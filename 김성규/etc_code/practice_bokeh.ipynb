# %%
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh import *
from bokeh.palettes import Spectral5
from bokeh.embed import components
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
from bokeh.io import output_notebook, show

#figure는 직접 그려주는애, output_notebook은 보여주는 것

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
a = pd.read_csv('csv_file/kr20_ver2.csv')
b = pd.read_csv('csv_file/corona_cases.csv')
c = pd.read_csv('csv_file/same_period_cases.csv')

# %%
# 스캐터 relation
p= figure(plot_width=800, plot_height=400)
# x=b['year_month']
# y=b['total_cases']
# x=[0,1,2,3,4]
# y=[0,1,2,3,4]

x=b['total_cases']
y=b['death']

p.circle(x, y, size=5)
show(p)
# Out:
#   <div class="bk-root" id="7f832a8f-39c4-44a1-bd3b-464705dbce61" data-root-id="1880"></div>

# %%
# 스캐터 relation
p= figure(plot_width=800, plot_height=400)
# x=b['year_month']
# y=b['total_cases']
# x=[0,1,2,3,4]
# y=[0,1,2,3,4]

x=b['total_cases']
y=b['total_death']

p.circle(x, y, size=5)
show(p)
# Out:
#   <div class="bk-root" id="ea2983f0-ed36-4de8-9918-c2cea15ee076" data-root-id="2048"></div>

# %%
b = pd.read_csv('csv_file/corona_cases.csv')
b.to_csv('csv_file/corona_cases.csv', sep=',', index=False, encoding='utf-8-sig')

# %%
#나중에 그래프 합칠때랑, y축 axis 더 추가할 떄 필요
from numpy import arange, linspace, pi, sin

from bokeh.models import LinearAxis, Range1d


x = arange(-2*pi, 2*pi, 0.1)
y = sin(x)
y2 = linspace(0, 100, len(y))

p = figure(x_range=(-6.5, 6.5), y_range=(-1.1, 1.1))

p.circle(x, y, color="red")

p.extra_y_ranges = {"foo": Range1d(start=0, end=100)}
p.circle(x, y2, color="blue", y_range_name="foo")
p.add_layout(LinearAxis(y_range_name="foo"), 'left')

show(p)
# Out:
#   <div class="bk-root" id="18d7036f-542d-47d7-9000-92c695542e1c" data-root-id="2631"></div>

# %%
b
# Out:
#            date local_outbreak  imported_cases  death  new_cases  total_cases  \
# 0    2020-01-21              0               0      0          0            0
# 1    2020-01-22              0               0      0          0            0
# 2    2020-01-23              0               0      0          0            0
# 3    2020-01-24              0               1      0          1            1
# 4    2020-01-25              0               0      0          0            1
# ..          ...            ...             ...    ...        ...          ...
# 653  2021-11-04          2,457              25     24       2482       373119
# 654  2021-11-05          2,323              20     20       2343       375462
# 655  2021-11-06          2,218              29     20       2247       377709
# 656  2021-11-07          2,204              20     11       2224       379933
# 657  2021-11-08          1,733              27     13       1760       381693
#
#      variation year_month
# ...

# %%
b = pd.read_csv('csv_file/corona_cases_ver2.csv')
b
# Out:
#            date local_outbreak  imported_cases  death  total_death  new_cases  \
# 0    2020-01-21              0               0      0            0          0
# 1    2020-01-22              0               0      0            0          0
# 2    2020-01-23              0               0      0            0          0
# 3    2020-01-24              0               1      0            0          1
# 4    2020-01-25              0               0      0            0          0
# ..          ...            ...             ...    ...          ...        ...
# 653  2021-11-04          2,457              25     24         2916       2482
# 654  2021-11-05          2,323              20     20         2936       2343
# 655  2021-11-06          2,218              29     20         2956       2247
# 656  2021-11-07          2,204              20     11         2967       2224
# 657  2021-11-08          1,733              27     13         2980       1760
#
# ...

# %%
tips3 = pd.read_csv('csv_file/corona_cases_ver2.csv')
tips3['date'] = pd.to_datetime(tips3['date'])
tips3['year'] = tips3['date'].dt.year
tips3['month'] = tips3['date'].dt.month
tips3['year_month'] = tips3['year'].map(str) + '-' + tips3['month'].map(str)
tips3['year_month'] = pd.to_datetime(tips3['year_month'], format='%Y-%m').dt.strftime('%y-%m')

tips3.drop(['year', 'month'], axis=1, inplace=True)
tips3.to_csv('csv_file/corona_cases_ver2.csv', sep=',', index=False)

# %%
tips3 = pd.read_csv('csv_file/corona_cases_ver2.csv')
tips3
# Out:
#            date local_outbreak  imported_cases  death  total_death  new_cases  \
# 0    2020-01-21              0               0      0            0          0
# 1    2020-01-22              0               0      0            0          0
# 2    2020-01-23              0               0      0            0          0
# 3    2020-01-24              0               1      0            0          1
# 4    2020-01-25              0               0      0            0          0
# ..          ...            ...             ...    ...          ...        ...
# 653  2021-11-04          2,457              25     24         2916       2482
# 654  2021-11-05          2,323              20     20         2936       2343
# 655  2021-11-06          2,218              29     20         2956       2247
# 656  2021-11-07          2,204              20     11         2967       2224
# 657  2021-11-08          1,733              27     13         2980       1760
#
# ...

# %%
# 스캐터 relation
p= figure(plot_width=800, plot_height=400)

x=b['total_cases']
y=b['total_death']

p.circle(x, y, size=5, line_color='orange', fill_color='navy')
show(p)
# Out:
#   <div class="bk-root" id="8d97b9ea-2b16-4124-ab1c-353eb2bc12e6" data-root-id="3082"></div>

# %%
# 스캐터 relation
p= figure(plot_width=800, plot_height=400)

x=b['total_cases']
y=b['total_death']

p.circle(x, y, size=15, line_color='orange', fill_color='navy', fill_alpha=0.2)
show(p)
# Out:
#   <div class="bk-root" id="639fa1c0-b11a-4e0a-a8f3-8d838e3b08f6" data-root-id="3781"></div>

# %%
#날짜데이터(문자열) -> time데이터로 타입변환 / a=유튜브 , b=코로나
pd.to_datetime(a['trending_date'])
pd.to_datetime(b['date'])
# Out:
# 0     2020-01-21
# 1     2020-01-22
# 2     2020-01-23
# 3     2020-01-24
# 4     2020-01-25
#          ...
# 653   2021-11-04
# 654   2021-11-05
# 655   2021-11-06
# 656   2021-11-07
# 657   2021-11-08
# Name: date, Length: 658, dtype: datetime64[ns]

# %%
a.index = pd.to_datetime(a['trending_date'])
b.index = pd.to_datetime(b['date'])
a = a.drop(['trending_date'], axis=1)
b = b.drop(['date'], axis=1)

# %%
a
# Out:
#                                                            title  \
# trending_date
# 2020-08-12                                           안녕하세요 보겸입니다
# 2020-08-12                                    부락토스의 계획 [총몇명 프리퀄]
# 2020-08-12                                       평생 반성하면서 살겠습니다.
# 2020-08-12                                  안녕하세요 꽈뚜룹입니다.
# 2020-08-12      박진영 (J.Y. Park) When We Disco (Duet with 선미) M/V
# ...                                                          ...
# 2021-11-07                                KT에 한달에 50만원 쓰는 사람의 최후
# 2021-11-07     [김장장TV 이십세기들 ep.66] 돈 많이 번 장항준!왜 아직도 윤종신한텐 얻어먹을까?
# 2021-11-07                      *실제상황* 지진이 왔을때 일본인아내의 반응 #shorts
# 2021-11-07                         누리호가 찍은 지구! 누리호 동체 탑재카메라 촬영영상
# 2021-11-07     [전지적 참견 시점 선공개] 안영미와 깍쟁이 남편의 깨 쏟아지는 통화📞💞 , MBC...
#
#                    channel_title  category_id          publish_time  \
# trending_date
# 2020-08-12                 보겸 BK           24  2020-08-09T09:32:48Z
# ...

# %%
b
# Out:
#            local_outbreak  imported_cases  death  total_death  new_cases  \
# date
# 2020-01-21              0               0      0            0          0
# 2020-01-22              0               0      0            0          0
# 2020-01-23              0               0      0            0          0
# 2020-01-24              0               1      0            0          1
# 2020-01-25              0               0      0            0          0
# ...                   ...             ...    ...          ...        ...
# 2021-11-04          2,457              25     24         2916       2482
# 2021-11-05          2,323              20     20         2936       2343
# 2021-11-06          2,218              29     20         2956       2247
# 2021-11-07          2,204              20     11         2967       2224
# 2021-11-08          1,733              27     13         2980       1760
#
#             total_cases  variation
# date
# 2020-01-21            0          0
# ...

# %%
p = figure(plot_width=700, plot_height=300, x_axis_type='datetime')
p.line(b.index, b['new_cases'], color='navy', alpha=0.5)
show(p)
# Out:
#   <div class="bk-root" id="9b35b6ab-905c-4c87-9fc4-9ce01630023e" data-root-id="4981"></div>

# %%
import jinja2
from bokeh.embed import components
template = jinja2.Template('''\
<html>
<link href='http://cdn.pydata.org/bokeh/release/bokeh-2.3.2.min.css' rel='stylesheet' type='text/css'>
<script src='http://cdn.pydata.org/bokeh/release/bokeh-2.3.2.min.js'></script>
<head><title>bokeh test</title>
</head>
<body>
<h1>This site for Bokeh Test</h1>
{{script}}
{{div}}
</body>
</html>
''')

# %%
#이제 이 script랑 div에는 html관한 정보가 쓰여있음
script, div=components(p)

from IPython.display import HTML
HTML(template.render(script=script, div=div))
# Out:
# <html>
# <link href='http://cdn.pydata.org/bokeh/release/bokeh-2.3.2.min.css' rel='stylesheet' type='text/css'>
# <script src='http://cdn.pydata.org/bokeh/release/bokeh-2.3.2.min.js'></script>
# <head><title>bokeh test</title>
# </head>
# <body>
# <h1>This site for Bokeh Test</h1>
#
# <script type="text/javascript">
#     (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
#               (function(root) {
#                 function embed_document(root) {
#
# ...

# %%
#어떤 데이터가 쓰여있나 확인하면 html 구문이 쓰여있는걸확인할 수 있음
template.render(script=script, div=div)
# Out:
# '<html>\n<link href=\'http://cdn.pydata.org/bokeh/release/bokeh-2.3.2.min.css\' rel=\'stylesheet\' type=\'text/css\'>\n<script src=\'http://cdn.pydata.org/bokeh/release/bokeh-2.3.2.min.js\'></script>\n<head><title>bokeh test</title>\n</head>\n<body>\n<h1>This site for Bokeh Test</h1>\n\n<script type="text/javascript">\n    (function() {\n          var fn = function() {\n            Bokeh.safely(function() {\n              (function(root) {\n                function embed_document(root) {\n                  \n                var docs_json = \'{"844080e9-3935-4d45-8538-5ddd4339b338":{"defs":[],"roots":{"references":[{"attributes":{"below":[{"id":"4990"}],"center":[{"id":"4993"},{"id":"4997"}],"height":300,"left":[{"id":"4994"}],"renderers":[{"id":"5015"}],"title":{"id":"5174"},"toolbar":{"id":"5005"},"width":700,"x_range":{"id":"4982"},"x_scale":{"id":"4986"},"y_range":{"id":"4984"},"y_scale":{"id":"4988"}},"id":"4981","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"5196","typ
# ...

# %%
# 그래프 만든것 html 형식으로 저장하고, 불러오는 식
with open('b.html', 'w') as f:
    f.write(template.render(script=script, div=div))
import webbrowser
webbrowser.open('a.html')
# Out:
# True
